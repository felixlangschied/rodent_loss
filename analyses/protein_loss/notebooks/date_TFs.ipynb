# %% [markdown]
# ## Imports

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Input
#
# * mapping file generated with Ensembl BioMart

# %%
PROJECTDIR = Path('.').resolve().parents[2]

htdb_path = '../data/DatabaseExtract_v_1.01.csv'
pp_path = '../data/all_human_across_mammalia.phyloprofile'
map_path = '../data/human_tfs_ensembl2uniprot.txt'
phylostrata_path = '../data/htdb_tfs_uniprot2lca.json'

# %% [markdown]
# ## Output

# %%
phylostrata_overview = f'{PROJECTDIR}/publication/supplement_tables/TF_phylostrata.tsv'
non_conserved_phyloprofile = '../results/nonconserved_human_TFs.phyloprofile'

# %% [markdown]
# ## Load data

# %%
from collections import defaultdict

def all_htdb_tfs(path):
    df = pd.read_csv(path, sep=',', index_col=0)
    df = df[df['Is TF?'] == 'Yes']
    display(df)
    return set(df['HGNC symbol'])


def load_ensembl2uniprot(path):
    ensembl2uniprot = defaultdict(set)
    no_uniprot = set()
    all_uniprots = set()
    with open(path) as fh:
        header = next(fh)
        for i, line in enumerate(fh, 1):
            linedata = line.strip().split()
            if len(linedata) == 2:
                uniprot, ensembl = linedata
                ensembl2uniprot[ensembl].add(uniprot)
                
                all_uniprots.add(uniprot)
            elif len(linedata) == 3:
                swissprot, trembl, ensembl = linedata
                
                ensembl2uniprot[ensembl].add(swissprot)
                ensembl2uniprot[ensembl].add(trembl)
                
                all_uniprots.add(swissprot)
                all_uniprots.add(trembl)
            elif len(linedata) == 1:
                no_uniprot.add(linedata[0])
            else:
                raise ValueError(linedata)
    print(f'Warning: no Uniprot ID found for {len(no_uniprot)} out of {i} Ensembl IDs')
    return all_uniprots

    

tf_uniprot_ids = load_ensembl2uniprot(map_path)
# all_tfs = all_htdb_tfs(htdb_path)
print(tf_uniprot_ids)
# Out:
# Warning: no Uniprot ID found for 44 out of 6413 Ensembl IDs
# {'A0A024R4I3', 'G4XH65', 'A0A8Q3WLD2', 'H0YBB6', 'K7EQA0', 'O75364', 'C9JD04', 'Q92949', 'Q15583', 'Q99607', 'Q8N8L2', 'F5H771', 'A0A024R0P4', 'M0QXC7', 'A0A6E1WCP9', 'Q5VV16', 'F8W1Q1', 'E9PQ00', 'A0A804HJJ4', 'Q5T0B9', 'A6NJT0', 'A0A286YEX4', 'K7EJ04', 'B7WNT5', 'Q96GC6', 'A0A024QZG5', 'A0A6Q8PH19', 'A0A2P9DTZ8', 'A0A494C0H2', 'O75971', 'Q8IW36', 'M0QYP0', 'A0A994J813', 'K7EJ55', 'H0YNI2', 'Q9NX45', 'P32242', 'Q4W5G0', 'M0QXM7', 'A0A087WW29', 'Q6V3B1', 'A0A087WY37', 'Q9Y4X4', 'Q9ULX6', 'A0A1B0GVC6', 'C9IZC5', 'H3BPU3', 'Q15744', 'X6RBL6', 'D6R992', 'A0A3B3ISB7', 'E7EV44', 'Q86V93', 'A0A0D9SGE5', 'P09629', 'F5H8K3', 'A0A087X1H1', 'A0A024RBA3', 'A0A994J5Q4', 'A0A669KAX1', 'Q8WVJ9', 'C9JLQ8', 'A0A6Q8PHQ3', 'D6RC00', 'Q15
 'F8WB93', 'Q5SQQ9', 'M0R1X5', 'K7EMG8', 'H7C589', 'Q6P6D5', 'A0A8V8TMV6', 'B5MDG7', 'Q02930', 'M0R098', 'U3KQ96', 'A0A024R7K5', 'A0A8V8TPM6', 'Q15047', 'Q5T7W0', 'Q14872', 'B0QZ51', 'Q10587', 'A0A1B0GTK2', 'A0A3B3ISK8', 'M0R090', 'E7EQB2', 'K7EIN3', 'P54821', 'I3L3V0', 'E5RGQ1', 'C9JE35', 'H3BVE4', 'Q6EKJ0', 'E9PIN6', 'A0A087WYF4', 'Q9HBT8', 'A0A024R5Z3', 'A0A0D9SF71', 'F5H4P1', 'K7EIE0', 'H0Y4R8', 'A0A1B0GVE1', 'A0A3B3ITT2', 'A8MVF3', 'Q14469', 'A0A087WVA2', 'P17030', 'Q6PK81', 'J3QLW3', 'K7EIM5', 'A0A0C4DGI9', 'Q9H334', 'P40425', 'Q8TDD2', 'K7EKA0', 'H0Y7L6', 'A0A669KBL4', 'H3BRC5', 'Q86UP3', 'M0R171', 'F8W1B5', 'A0A0D9SEX8', 'K7EMH8', 'E9PJX9', 'A0A0U3FYV6', 'Q8HWS3', 'C9J896', 'E9PM99', 'A0A2R8Y8C8', 'Q96SZ4', 'F8VXG0', 'A0A140VKA5', 'A0A669KBA7', 'Q06710', 'A0A024R2C0', 'A0A024R0W2', 'A0A494C0T4', 'Q9H161', 'A0A024RCR3', 'J3KPM9', 'M0R136', 'A0A024R7B5', 'Q8IZ26', 'C9JCJ0', 'M0R0W9', 'H3BM94', 'O75123', 'A0A994J6X9', 'C9JBK9', 'Q03938', 'A0A024R6I1', 'M0R2T6', 'K7EP10', 'H3BPN8', 'Q99814', 'A0A087WV99', 'F8W652', 'J3KTA0', 'Q6NX49', 'Q8TF50', 'D6R9C0', 'M0QZ64', 'A0A6Q8PHH2', 'Q15406', 'D6REC2', 'Q8IVH2', 'F5H6N6', 'C9JMF0', 'Q99684', 'E9PN92', 'A0A3B3IT26', 'A0A087WZS6', 'A8MTY0', 'Q147U1', 'E9PL27', 'X5DQN9', 'C9JDI9', 'A0A2R8Y7P3', 'C9JKS0', 'A0A1B0GVI4', 'K7EMU0', 'Q9UJJ2', 'A0A0A0MRL5', 'Q8TD94', 'H0Y7K5', 'D6RDW0', 'K7EL77', 'A0A7P0Q1F0', 'A0A087X1F9', 'J3KSA1', 'K7ELB7', 'H7BXP3', 'Q6P9A1', 'A0A6E1XE14', 'C9JFG0', 'H0YCI1', 'E5RHR6', 'P08151', 'Q9BZM3', 'A0A024 ...

# %% [markdown]
# ## Filter PhlyoProfile
#
# * Only keep first co-ortholog (i.e. TF is present in species), so you can transform to wide format

# %%
def tfs_in_pp(path, uniprot_ids):
    with open(path) as fh:
        header = next(fh)
        col = []
        for line in fh:
            # print(line)
            uniprotid, taxid, orthoid, fasf, fasb = line.strip().split()
            if uniprotid in uniprot_ids:
                int_taxid = int(taxid.replace('ncbi', ''))
                col.append([uniprotid, int_taxid])
        
        df = pd.DataFrame(col, columns=['uniprotid', 'taxid'])
        df = df.drop_duplicates()
        wide_df = pd.crosstab(df['uniprotid'], df['taxid'])
        return wide_df
    
tfs_pp = tfs_in_pp(pp_path, tf_uniprot_ids)
display(tfs_pp)
# Out:
# taxid       9258     9261     9305     9337     9361     9365     9371     \
# uniprotid
# A0A087WUV0        0        1        0        1        1        1        1
# A0AVK6            1        1        1        1        1        1        1
# A0PJY2            1        1        1        1        1        1        1
# A1A519            0        0        0        0        1        1        1
# A1YPR0            1        1        1        1        1        1        1
# ...             ...      ...      ...      ...      ...      ...      ...
# Q9Y6Q9            1        1        1        1        1        1        1
# Q9Y6R6            1        1        1        1        1        0        1
# Q9Y6X0            1        1        1        1        1        1        1
# Q9Y6X8            1        1        1        1        1        1        1
# Q9Y6Y1            1        1        1        1        1        1        1
#
# taxid       9402     9407     9417     ...  591936   885580   1026970  \
# uniprotid                              ...
# A0A087WUV0        1        1        1  ...        1        1        1
# A0AVK6            1        1        1  ...        1        1        1
# A0PJY2            1        1        1  ...        1        1        1
# A1A519            1        1        1  ...        1        1        1
# A1YPR0            1        1        1  ...        1        1        1
# ...             ...      ...      ...  ...      ...      ...      ...
# Q9Y6Q9            1        1        1  ...        1        1        1
# Q9Y6R6            0        1        0  ...        1        0        0
# Q9Y6X0            1        1        1  ...        1        1        1
# Q9Y6X8            1        1        1  ...        1        1        1
# Q9Y6Y1            1        1        1  ...        1        1        1
#
# taxid       1047088  1230840  1574408  1608482  1706337  1868482  2715852
# uniprotid
# A0A087WUV0        1        1        1        1        1        1        1
# A0AVK6            1        1        1        1        1        1        1
# A0PJY2            1        1        1        1        1        1        1
# A1A519            1        1        1        1        1        1        1
# A1YPR0            1        1        1        1        1        0        1
# ...             ...      ...      ...      ...      ...      ...      ...
# Q9Y6Q9            0        1        1        1        1        1        1
# Q9Y6R6            1        0        1        1        1        1        1
# Q9Y6X0            1        1        1        1        1        1        1
# Q9Y6X8            1        1        1        1        1        0        1
# Q9Y6Y1            1        1        1        1        1        1        1
#
# [1604 rows x 169 columns]

# %%
from ete3 import NCBITaxa
from tqdm import tqdm
import json
import os


def phylostrata(df):
    ncbi = NCBITaxa()
    
    taxid_array = df.apply(lambda row: [col for col in df.columns if row[col] == 1], axis=1)
    uniprot2lca = {}
    for uniprotid, taxids in tqdm(taxid_array.items()):
        tree = ncbi.get_topology(taxids)
        lca_node = tree.get_common_ancestor([str(taxid) for taxid in taxids])
        lca_taxid = lca_node.name
        lca_name = list(ncbi.get_taxid_translator([lca_taxid]).values())[0]
        uniprot2lca[uniprotid] = lca_name
    
    return uniprot2lca
    
 
if not os.path.isfile(phylostrata_path):
    uniprot2lca = phylostrata(tfs_pp)
    with open(phylostrata_path, 'w') as of:
        json.dump(uniprot2lca, of)
else:
    with open(phylostrata_path) as fh:
        uniprot2lca = json.load(fh)
        
print(uniprot2lca)
# Out:
ia', 'O15522': 'Theria', 'O15525': 'Mammalia', 'O15535': 'Theria', 'O43147': 'Mammalia', 'O43151': 'Mammalia', 'O43167': 'Mammalia', 'O43186': 'Eutheria', 'O43189': 'Mammalia', 'O43248': 'Mammalia', 'O43296': 'Mammalia', 'O43298': 'Mammalia', 'O43309': 'Mammalia', 'O43313': 'Mammalia', 'O43316': 'Mammalia', 'O43345': 'Mammalia', 'O43361': 'Mammalia', 'O43364': 'Mammalia', 'O43365': 'Mammalia', 'O43422': 'Mammalia', 'O43435': 'Mammalia', 'O43474': 'Mammalia', 'O43524': 'Mammalia', 'O43623': 'Mammalia', 'O43638': 'Theria', 'O43670': 'Mammalia', 'O43680': 'Mammalia', 'O43711': 'Mammalia', 'O43763': 'Mammalia', 'O43823': 'Mammalia', 'O43829': 'Mammalia', 'O43889': 'Mammalia', 'O43918': 'Mammalia', 'O60248': 'Mammalia', 'O60281': 'Mammalia', 'O60284': 'Mammalia', 'O60304': 'Mammalia', 'O60315': 'Mammalia', 'O60381': 'Mammalia', 'O60393': 'Mammalia', 'O60422': 'Eutheria', 'O60479': 'Mammalia', 'O60481': 'Mammalia', 'O60519': 'Mammalia', 'O60548': 'Theria', 'O60663': 'Mammalia', 'O60675': 'Mammalia', 'O60678': 'Mammalia', 'O60682': 'Mammalia', 'O60765': 'Mammalia', 'O60806': 'Mammalia', 'O60870': 'Mammalia', 'O60902': 'Mammalia', 'O75030': 'Mammalia', 'O75123': 'Mammalia', 'O75132': 'Mammalia', 'O75290': 'Mammalia', 'O75333': 'Theria', 'O75346': 'Mammalia', 'O75360': 'Mammalia', 'O75362': 'Mammalia', 'O75364': 'Mammalia', 'O75373': 'Mammalia', 'O75398': 'Mammalia', 'O75437': 'Mammalia', 'O75444': 'Theria', 'O75461': 'Mammalia', 'O75467': 'Eutheria', 'O75469': 'Theria', 'O75541': 'Mammalia', 'O75564': 'Mammalia', 'O75593': 'Mammalia', 'O75603': 'Mammalia', 'O75626': 'Mammalia', 'O75820': 'Mammalia', 'O75840': 'Mammalia', 'O75971': 'Mammalia', 'O94892': 'Mammalia', 'O94916': 'Mammalia', 'O94983': 'Mammalia', 'O94993': 'Mammalia', 'O95076': 'Mammalia', 'O95096': 'Mammalia', 'O9512 ...

# %% [markdown]
# ## Count LCAs

# %%
from collections import Counter

c = Counter(uniprot2lca.values())
display(c)
# Out:
# Counter({'Mammalia': 1347,
#          'Theria': 172,
#          'Eutheria': 67,
#          'Boreoeutheria': 11,
#          'Euarchontoglires': 3,
#          'Simiiformes': 1,
#          'Haplorrhini': 1,
#          'Primates': 1,
#          'Homo sapiens': 1})

# %% [markdown]
# ## Find conserved and non-conserved TFs
#
# * for each lca, how large is the maximum?

# %%
def maximum_orthologs_per_LCA(df, counter):
    ncbi = NCBITaxa()
    
    lca2members = {}
    # get the NCBI taxonomy tree for all taxa
    alltaxa = list(df.columns)
    tree = ncbi.get_topology(alltaxa)
    # get the node of each possible LCA
    lca_name2taxidlist = ncbi.get_name_translator(dict(counter).keys())
    # extract subtrees for each LCA
    for lca_name, taxidlist in lca_name2taxidlist.items():
        taxid = taxidlist[0]
        # print(taxid)
        subtree = tree.search_nodes(name=str(taxid))[0]
        num_taxa = len(subtree)
        
        lca2members[lca_name] = num_taxa
    return lca2members


    
lca2members = maximum_orthologs_per_LCA(tfs_pp, c)
print(lca2members)
# Out:
# {'Boreoeutheria': 153, 'Euarchontoglires': 65, 'Eutheria': 161, 'Haplorrhini': 26, 'Homo sapiens': 1, 'Mammalia': 169, 'Primates': 29, 'Simiiformes': 25, 'Theria': 167}

# %% [markdown]
# ## Put everything together

# %%
def join_results(tfs_pp, uniprot2lca, lca2members):
    sum_array = tfs_pp.sum(axis=1)
    uniprot2lca = pd.DataFrame.from_dict(uniprot2lca, orient='index', columns=['gained_in'])
    df = uniprot2lca.join(pd.DataFrame(sum_array, columns=['number_orthologs']))
    memberdf = pd.DataFrame.from_dict(lca2members, orient='index', columns=['maximum_number'])
    df = df.merge(memberdf, left_on='gained_in', right_index=True)
    return df


def find_conserved(df, min_fraction=0.95):
    df['fraction'] =  df.number_orthologs / df.maximum_number
    df['strict_core'] = df['fraction'] == 1.0
    df['conserved_min_95percent'] = df['fraction'] > min_fraction
    return df

    
    
    
summary = join_results(tfs_pp, uniprot2lca, lca2members)
overview = find_conserved(summary)
display(overview)
overview.to_csv(phylostrata_overview, sep='\t', index=False)
# Out:
#            gained_in  number_orthologs  maximum_number  fraction  strict_core  \
# A0A087WUV0  Mammalia               142             169  0.840237        False
# A0AVK6      Mammalia               169             169  1.000000         True
# A0PJY2      Mammalia               168             169  0.994083        False
# A1A519        Theria               163             167  0.976048        False
# A1YPR0      Mammalia               168             169  0.994083        False
# ...              ...               ...             ...       ...          ...
# Q9Y6Q9      Mammalia               168             169  0.994083        False
# Q9Y6R6      Mammalia                84             169  0.497041        False
# Q9Y6X0      Mammalia               169             169  1.000000         True
# Q9Y6X8      Mammalia               168             169  0.994083        False
# Q9Y6Y1      Mammalia               169             169  1.000000         True
#
#             conserved_min_95percent
# A0A087WUV0                    False
# A0AVK6                         True
# A0PJY2                         True
# A1A519                         True
# A1YPR0                         True
# ...                             ...
# Q9Y6Q9                         True
# Q9Y6R6                        False
# Q9Y6X0                         True
# Q9Y6X8                         True
# Q9Y6Y1                         True
#
# [1604 rows x 6 columns]

# %% [markdown]
# ## Filter PhyloProfile

# %%
non_conserved = overview[~overview.conserved_min_95percent]
print(Counter(non_conserved.gained_in))
display(non_conserved)
#non_conserved_phyloprofile

with open(pp_path) as fh:
    header = next(fh)
    col = [header]
    for line in fh:
        uniprotid = line.split()[0]
        if uniprotid in non_conserved.index:
            col.append(line)
            
with open(non_conserved_phyloprofile, 'w') as of:
    for line in col:
        of.write(line)
# Out:
# Counter({'Mammalia': 378, 'Theria': 136, 'Eutheria': 54, 'Boreoeutheria': 11, 'Euarchontoglires': 3, 'Simiiformes': 1, 'Haplorrhini': 1, 'Primates': 1})
#            gained_in  number_orthologs  maximum_number  fraction  \
# A0A087WUV0  Mammalia               142             169  0.840237
# A2RRD8      Mammalia                67             169  0.396450
# A6NCS4      Mammalia               156             169  0.923077
# A6NFQ7        Theria               104             167  0.622754
# A6NGD5      Eutheria               139             161  0.863354
# ...              ...               ...             ...       ...
# Q9Y5W3      Mammalia               150             169  0.887574
# Q9Y603        Theria               104             167  0.622754
# Q9Y651      Mammalia               145             169  0.857988
# Q9Y6Q3      Mammalia               153             169  0.905325
# Q9Y6R6      Mammalia                84             169  0.497041
#
#             conserved_min_95percent
# A0A087WUV0                    False
# A2RRD8                        False
# A6NCS4                        False
# A6NFQ7                        False
# A6NGD5                        False
# ...                             ...
# Q9Y5W3                        False
# Q9Y603                        False
# Q9Y651                        False
# Q9Y6Q3                        False
# Q9Y6R6                        False
#
# [585 rows x 5 columns]

# %%
conserved = overview[overview.conserved_min_95percent]
display(conserved)

print(Counter(conserved.gained_in))
# Out:
#        gained_in  number_orthologs  maximum_number  fraction  \
# A0AVK6  Mammalia               169             169  1.000000
# A0PJY2  Mammalia               168             169  0.994083
# A1A519    Theria               163             167  0.976048
# A1YPR0  Mammalia               168             169  0.994083
# A2RU54  Mammalia               163             169  0.964497
# ...          ...               ...             ...       ...
# Q9Y692  Mammalia               169             169  1.000000
# Q9Y6Q9  Mammalia               168             169  0.994083
# Q9Y6X0  Mammalia               169             169  1.000000
# Q9Y6X8  Mammalia               168             169  0.994083
# Q9Y6Y1  Mammalia               169             169  1.000000
#
#         conserved_min_95percent
# A0AVK6                     True
# A0PJY2                     True
# A1A519                     True
# A1YPR0                     True
# A2RU54                     True
# ...                         ...
# Q9Y692                     True
# Q9Y6Q9                     True
# Q9Y6X0                     True
# Q9Y6X8                     True
# Q9Y6Y1                     True
#
# [1019 rows x 5 columns]
# Counter({'Mammalia': 969, 'Theria': 36, 'Eutheria': 13, 'Homo sapiens': 1})

# %%
strict_core = overview[overview.strict_core]
print(Counter(strict_core.gained_in))
display(strict_core)
# Out:
# Counter({'Mammalia': 330, 'Theria': 7, 'Eutheria': 2, 'Homo sapiens': 1})
#        gained_in  number_orthologs  maximum_number  fraction  strict_core  \
# A0AVK6  Mammalia               169             169       1.0         True
# A6NI15  Mammalia               169             169       1.0         True
# A6NNA5  Mammalia               169             169       1.0         True
# O00321  Mammalia               169             169       1.0         True
# O00409  Mammalia               169             169       1.0         True
# ...          ...               ...             ...       ...          ...
# Q9Y5R5  Mammalia               169             169       1.0         True
# Q9Y5X4  Mammalia               169             169       1.0         True
# Q9Y692  Mammalia               169             169       1.0         True
# Q9Y6X0  Mammalia               169             169       1.0         True
# Q9Y6Y1  Mammalia               169             169       1.0         True
#
#         conserved_min_95percent
# A0AVK6                     True
# A6NI15                     True
# A6NNA5                     True
# O00321                     True
# O00409                     True
# ...                         ...
# Q9Y5R5                     True
# Q9Y5X4                     True
# Q9Y692                     True
# Q9Y6X0                     True
# Q9Y6Y1                     True
#
# [340 rows x 6 columns]
